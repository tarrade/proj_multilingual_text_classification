# %% [markdown]
# # Exploring data with BigQuery

# %%
from IPython.display import display, Markdown
with open('../../doc/env_variables_setup.md', 'r') as fh:
    content = fh.read()
display(Markdown(content))
# Out:
# Environment variables that need to be defined:
# `export DIR_PROJ=your_path_git_repository`
# `export PYTHONPATH=$DIR_PROJ/src`
# `export PATH_TENSORBOARD=your_path_tensorboard`
# `export PATH_DATASETS=your_path_datasets`
# `export PROJECT_ID=your_gcp_project_id`
# `export BUCKET_NAME=your_gcp_gs_bucket_name`
# `export REGION=your_region`
# `export MODEL_DIR_ESTIMATOR_PATH=your_path_to_save_model`
#
# - Use local Jupyter Lab
#     - you need to have the `jupyter-notebook` Anaconda python environment created [link](local_jupyter_lab_installation.md)
#     - you need to have the `jupyter-notebook` Anaconda python environment activated [link](local_jupyter_lab_installation.md)
#     - then define the environment variables above (copy and paste)
#     - you need to have the `env_multilingual_class` Anaconda python environment created [link](local_jupyter_lab_installation.md)
#     - start Jupyter Lab:  `jupyter lab`
#     - open a Jupyter Lab notebook from `notebook/`
#      - clone this repositiory: `git clone https://github.com/tarrade/proj_multilingual_text_classification.git`
#     - choose the proper Anaconda python environment:  `Python [conda env:env_multilingual_class]` [link](conda_env.md)
#     - clone this repositiory: `git clone https://github.com/tarrade/proj_multilingual_text_classification.git`
#
#
# - Use GCP Jupyter Lab
#     - Go on GCP
#     - open a Cloud Shell
#     - `ssh-keygen -t rsa -b 4096 -C firstName_lastName`
#     - `cp .ssh/id_rsa.pub .`
#     - use Cloud Editor to edit this file `id_rsa.pub` and copy the full content
#     - Go on Compute Engine -> Metadata
#     - Click SSH Keys
#     - Click Edit
#     - Click + Add item, copy the content of `id_rsa.pub`
#     - You should see firstName_lastName of the left
#     - Click Save
#     - you need to start a AI Platform instance
#     - open a Jupyter Lab terminal and got to `/home/gcp_user_name/`
#     - clone this repositiory: `git clone https://github.com/tarrade/proj_multilingual_text_classification.git`
#     - then `cd proj_multilingual_text_classification/`
#     - create the Anacond Python environment `conda env create -f env/environment.yml`
#     - create a file `config.sh` in `/home` with the following information:
#     ```
#     #!/bin/bash
#
#     echo "applying some configuration ..."
#     git config --global user.email user_email
#     git config --global user.name user_name
#     git config --global credential.helper store
#
#     # Add here the enviroment variables from above below
#     export DIR_PROJ= ...
#     ...
#
#     cd /home/gcp_user_name/
#
#     conda activate env_multilingual_class
#
#     export PS1="[\e\]\u@:\[\e\]\w/]$"
#     ```
#     - Got to AI Platform Notebook, select your instance and click "Reset".
#     - Wait and reshreh you Web browser with the Notebook

# %% [markdown]
# ## Import libraries

# %%
# Import the client library
import sys
import os
import pathlib
import google.cloud.dlp
import subprocess
import json 
import requests
import getpass
import urllib.parse

# %% [markdown]
# ## Defined/checked GCP env variables

# %%
try:
    tmp=os.environ['PROJECT_ID']
except:
    print('Env variable PROJECT not defined!') 

try:
    tmp=os.environ['BUCKET_NAME']
except:
    print('Env variable BUCKET_NAME not defined!') 
    
try:    
    tmp=os.environ['GOOGLE_APPLICATION_CREDENTIALS']
except:
    print('Env variable GOOGLE_APPLICATION_CREDENTIALS not defined!') 

try:
    tmp=os.environ['REQUESTS_CA_BUNDLE']
except:
    print('Env variable REQUESTS_CA_BUNDLE not defined!') 

try:
    tmp=os.environ['AXA_CH_CA_BUNDLE']
except:
    print('Env variable AXA_CA_CA_BUNDLE not defined!')
# Out:
# Env variable GOOGLE_APPLICATION_CREDENTIALS not defined!
# Env variable REQUESTS_CA_BUNDLE not defined!
# Env variable AXA_CA_CA_BUNDLE not defined!

# %% [markdown]
# ## Test of the proxy with Gloud Storage

# %%
from google.cloud import storage
storage_client = storage.Client()
buckets = storage_client.list_buckets()

for bucket in buckets:
    print(bucket.name)
    

blobs = storage_client.list_blobs(os.environ['BUCKET_NAME'])
for blob in blobs:
    print(blob.name)
    break
# Out:
# artifacts.nlp-text-classification.appspot.com
# dataflow-staging-us-central1-1056584964721
# nlp-text-classification
# nlp-text-classification-build-cache
# us.artifacts.nlp-text-classification.appspot.com
# beam/

# %% [markdown]
# ## Test of the proxy with BigQuery

# %%
from google.cloud import bigquery
client = bigquery.Client()

query = """SELECT
  EXTRACT(YEAR FROM creation_date) AS Year,
  COUNT(*) AS Number_of_Questions,
  ROUND(100 * SUM(IF(answer_count > 0, 1, 0)) / COUNT(*), 1) AS Percent_Questions_with_Answers
FROM
  `bigquery-public-data.stackoverflow.posts_questions`
GROUP BY
  Year
HAVING
  Year > 2008 AND Year < 2016
ORDER BY
  Year
"""
#df = client.query(query).to_dataframe()
#df.head()
query_job = client.query(query)
rows = query_job.result()  # Waits for query to finish

for row in rows:
    print(row)
# Out:
# Row((2009, 342861, 99.6), {'Year': 0, 'Number_of_Questions': 1, 'Percent_Questions_with_Answers': 2})
# Row((2010, 692888, 99.0), {'Year': 0, 'Number_of_Questions': 1, 'Percent_Questions_with_Answers': 2})
# Row((2011, 1197767, 97.2), {'Year': 0, 'Number_of_Questions': 1, 'Percent_Questions_with_Answers': 2})
# Row((2012, 1641742, 94.6), {'Year': 0, 'Number_of_Questions': 1, 'Percent_Questions_with_Answers': 2})
# Row((2013, 2054622, 91.7), {'Year': 0, 'Number_of_Questions': 1, 'Percent_Questions_with_Answers': 2})
# Row((2014, 2157464, 88.6), {'Year': 0, 'Number_of_Questions': 1, 'Percent_Questions_with_Answers': 2})
# Row((2015, 2211624, 86.5), {'Year': 0, 'Number_of_Questions': 1, 'Percent_Questions_with_Answers': 2})

# %% [markdown]
# ## Getting medatadata about the tables

# %%
# dataset_id = 'your-project.your_dataset'
dataset_id =  'bigquery-public-data.stackoverflow'
tables = client.list_tables(dataset_id)

print("Tables contained in '{}':".format(dataset_id))
for table in tables:
    print("{}.{}.{}".format(table.project, table.dataset_id, table.table_id))
# Out:
# Tables contained in 'bigquery-public-data.stackoverflow':
# bigquery-public-data.stackoverflow.badges
# bigquery-public-data.stackoverflow.comments
# bigquery-public-data.stackoverflow.post_history
# bigquery-public-data.stackoverflow.post_links
# bigquery-public-data.stackoverflow.posts_answers
# bigquery-public-data.stackoverflow.posts_moderator_nomination
# bigquery-public-data.stackoverflow.posts_orphaned_tag_wiki
# bigquery-public-data.stackoverflow.posts_privilege_wiki
# bigquery-public-data.stackoverflow.posts_questions
# bigquery-public-data.stackoverflow.posts_tag_wiki
# bigquery-public-data.stackoverflow.posts_tag_wiki_excerpt
# bigquery-public-data.stackoverflow.posts_wiki_placeholder
# bigquery-public-data.stackoverflow.stackoverflow_posts
# bigquery-public-data.stackoverflow.tags
# bigquery-public-data.stackoverflow.users
# bigquery-public-data.stackoverflow.votes

# %%
client = bigquery.Client()

query = """SELECT
 * EXCEPT(is_typed)
FROM
 `bigquery-public-data.stackoverflow`.INFORMATION_SCHEMA.TABLES
"""
df = client.query(query).to_dataframe()
df.head()
# Out:
#           table_catalog   table_schema               table_name  table_type  \
# 0  bigquery-public-data  stackoverflow            posts_answers  BASE TABLE
# 1  bigquery-public-data  stackoverflow                    users  BASE TABLE
# 2  bigquery-public-data  stackoverflow  posts_orphaned_tag_wiki  BASE TABLE
# 3  bigquery-public-data  stackoverflow           posts_tag_wiki  BASE TABLE
# 4  bigquery-public-data  stackoverflow      stackoverflow_posts  BASE TABLE
#
#   is_insertable_into                    creation_time
# 0                YES 2016-10-31 18:31:25.583000+00:00
# 1                YES 2016-10-26 13:29:37.954000+00:00
# 2                YES 2016-10-31 16:41:37.010000+00:00
# 3                YES 2016-10-31 16:22:35.603000+00:00
# 4                YES 2016-09-21 13:42:24.544000+00:00

# %%
client = bigquery.Client()

query = """SELECT
 * EXCEPT(is_generated, generation_expression, is_stored, is_updatable)
FROM
 `bigquery-public-data.stackoverflow`.INFORMATION_SCHEMA.COLUMNS
WHERE
 table_name="posts_answers"
"""
df = client.query(query).to_dataframe()
print(len(df))
df
# Out:
# 20
#            table_catalog   table_schema     table_name  \
# 0   bigquery-public-data  stackoverflow  posts_answers
# 1   bigquery-public-data  stackoverflow  posts_answers
# 2   bigquery-public-data  stackoverflow  posts_answers
# 3   bigquery-public-data  stackoverflow  posts_answers
# 4   bigquery-public-data  stackoverflow  posts_answers
# 5   bigquery-public-data  stackoverflow  posts_answers
# 6   bigquery-public-data  stackoverflow  posts_answers
# 7   bigquery-public-data  stackoverflow  posts_answers
# 8   bigquery-public-data  stackoverflow  posts_answers
# 9   bigquery-public-data  stackoverflow  posts_answers
# 10  bigquery-public-data  stackoverflow  posts_answers
# 11  bigquery-public-data  stackoverflow  posts_answers
# 12  bigquery-public-data  stackoverflow  posts_answers
# 13  bigquery-public-data  stackoverflow  posts_answers
# 14  bigquery-public-data  stackoverflow  posts_answers
# 15  bigquery-public-data  stackoverflow  posts_answers
# 16  bigquery-public-data  stackoverflow  posts_answers
# 17  bigquery-public-data  stackoverflow  posts_answers
# 18  bigquery-public-data  stackoverflow  posts_answers
# 19  bigquery-public-data  stackoverflow  posts_answers
#
#                  column_name  ordinal_position is_nullable  data_type  \
# 0                         id                 1         YES      INT64
# 1                      title                 2         YES     STRING
# 2                       body                 3         YES     STRING
# 3         accepted_answer_id                 4         YES     STRING
# 4               answer_count                 5         YES     STRING
# 5              comment_count                 6         YES      INT64
# 6       community_owned_date                 7         YES  TIMESTAMP
# 7              creation_date                 8         YES  TIMESTAMP
# 8             favorite_count                 9         YES     STRING
# 9         last_activity_date                10         YES  TIMESTAMP
# 10            last_edit_date                11         YES  TIMESTAMP
# 11  last_editor_display_name                12         YES     STRING
# 12       last_editor_user_id                13         YES      INT64
# 13        owner_display_name                14         YES     STRING
# 14             owner_user_id                15         YES      INT64
# 15                 parent_id                16         YES      INT64
# 16              post_type_id                17         YES      INT64
# 17                     score                18         YES      INT64
# 18                      tags                19         YES     STRING
# 19                view_count                20         YES     STRING
#
#    is_hidden is_system_defined is_partitioning_column  \
# 0         NO                NO                     NO
# 1         NO                NO                     NO
# 2         NO                NO                     NO
# 3         NO                NO                     NO
# 4         NO                NO                     NO
# 5         NO                NO                     NO
# 6         NO                NO                     NO
# 7         NO                NO                     NO
# 8         NO                NO                     NO
# 9         NO                NO                     NO
# 10        NO                NO                     NO
# 11        NO                NO                     NO
# 12        NO                NO                     NO
# 13        NO                NO                     NO
# 14        NO                NO                     NO
# 15        NO                NO                     NO
# 16        NO                NO                     NO
# 17        NO                NO                     NO
# 18        NO                NO                     NO
# 19        NO                NO                     NO
#
#    clustering_ordinal_position
# 0                         None
# 1                         None
# 2                         None
# 3                         None
# 4                         None
# 5                         None
# 6                         None
# 7                         None
# 8                         None
# 9                         None
# 10                        None
# 11                        None
# 12                        None
# 13                        None
# 14                        None
# 15                        None
# 16                        None
# 17                        None
# 18                        None
# 19                        None

# %%
client = bigquery.Client()

query = """SELECT
 * EXCEPT(is_generated, generation_expression, is_stored, is_updatable)
FROM
 `bigquery-public-data.stackoverflow`.INFORMATION_SCHEMA.COLUMNS
WHERE
 table_name="stackoverflow_posts"
"""
df = client.query(query).to_dataframe()
print(len(df))
df
# Out:
# 20
#            table_catalog   table_schema           table_name  \
# 0   bigquery-public-data  stackoverflow  stackoverflow_posts
# 1   bigquery-public-data  stackoverflow  stackoverflow_posts
# 2   bigquery-public-data  stackoverflow  stackoverflow_posts
# 3   bigquery-public-data  stackoverflow  stackoverflow_posts
# 4   bigquery-public-data  stackoverflow  stackoverflow_posts
# 5   bigquery-public-data  stackoverflow  stackoverflow_posts
# 6   bigquery-public-data  stackoverflow  stackoverflow_posts
# 7   bigquery-public-data  stackoverflow  stackoverflow_posts
# 8   bigquery-public-data  stackoverflow  stackoverflow_posts
# 9   bigquery-public-data  stackoverflow  stackoverflow_posts
# 10  bigquery-public-data  stackoverflow  stackoverflow_posts
# 11  bigquery-public-data  stackoverflow  stackoverflow_posts
# 12  bigquery-public-data  stackoverflow  stackoverflow_posts
# 13  bigquery-public-data  stackoverflow  stackoverflow_posts
# 14  bigquery-public-data  stackoverflow  stackoverflow_posts
# 15  bigquery-public-data  stackoverflow  stackoverflow_posts
# 16  bigquery-public-data  stackoverflow  stackoverflow_posts
# 17  bigquery-public-data  stackoverflow  stackoverflow_posts
# 18  bigquery-public-data  stackoverflow  stackoverflow_posts
# 19  bigquery-public-data  stackoverflow  stackoverflow_posts
#
#                  column_name  ordinal_position is_nullable  data_type  \
# 0                         id                 1          NO      INT64
# 1                      title                 2         YES     STRING
# 2                       body                 3         YES     STRING
# 3         accepted_answer_id                 4         YES      INT64
# 4               answer_count                 5         YES      INT64
# 5              comment_count                 6         YES      INT64
# 6       community_owned_date                 7         YES  TIMESTAMP
# 7              creation_date                 8         YES  TIMESTAMP
# 8             favorite_count                 9         YES      INT64
# 9         last_activity_date                10         YES  TIMESTAMP
# 10            last_edit_date                11         YES  TIMESTAMP
# 11  last_editor_display_name                12         YES     STRING
# 12       last_editor_user_id                13         YES      INT64
# 13        owner_display_name                14         YES     STRING
# 14             owner_user_id                15         YES      INT64
# 15                 parent_id                16         YES      INT64
# 16              post_type_id                17         YES      INT64
# 17                     score                18         YES      INT64
# 18                      tags                19         YES     STRING
# 19                view_count                20         YES      INT64
#
#    is_hidden is_system_defined is_partitioning_column  \
# 0         NO                NO                     NO
# 1         NO                NO                     NO
# 2         NO                NO                     NO
# 3         NO                NO                     NO
# 4         NO                NO                     NO
# 5         NO                NO                     NO
# 6         NO                NO                     NO
# 7         NO                NO                     NO
# 8         NO                NO                     NO
# 9         NO                NO                     NO
# 10        NO                NO                     NO
# 11        NO                NO                     NO
# 12        NO                NO                     NO
# 13        NO                NO                     NO
# 14        NO                NO                     NO
# 15        NO                NO                     NO
# 16        NO                NO                     NO
# 17        NO                NO                     NO
# 18        NO                NO                     NO
# 19        NO                NO                     NO
#
#    clustering_ordinal_position
# 0                         None
# 1                         None
# 2                         None
# 3                         None
# 4                         None
# 5                         None
# 6                         None
# 7                         None
# 8                         None
# 9                         None
# 10                        None
# 11                        None
# 12                        None
# 13                        None
# 14                        None
# 15                        None
# 16                        None
# 17                        None
# 18                        None
# 19                        None

# %%
client = bigquery.Client()

query = ("""
SELECT
 * 
FROM
 `bigquery-public-data.stackoverflow`.INFORMATION_SCHEMA.COLUMN_FIELD_PATHS
WHERE
 table_name="stackoverflow_posts"
""")
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query


df = query_job.to_dataframe()
print(len(df))
df
# Out:
# 20
#            table_catalog   table_schema           table_name  \
# 0   bigquery-public-data  stackoverflow  stackoverflow_posts
# 1   bigquery-public-data  stackoverflow  stackoverflow_posts
# 2   bigquery-public-data  stackoverflow  stackoverflow_posts
# 3   bigquery-public-data  stackoverflow  stackoverflow_posts
# 4   bigquery-public-data  stackoverflow  stackoverflow_posts
# 5   bigquery-public-data  stackoverflow  stackoverflow_posts
# 6   bigquery-public-data  stackoverflow  stackoverflow_posts
# 7   bigquery-public-data  stackoverflow  stackoverflow_posts
# 8   bigquery-public-data  stackoverflow  stackoverflow_posts
# 9   bigquery-public-data  stackoverflow  stackoverflow_posts
# 10  bigquery-public-data  stackoverflow  stackoverflow_posts
# 11  bigquery-public-data  stackoverflow  stackoverflow_posts
# 12  bigquery-public-data  stackoverflow  stackoverflow_posts
# 13  bigquery-public-data  stackoverflow  stackoverflow_posts
# 14  bigquery-public-data  stackoverflow  stackoverflow_posts
# 15  bigquery-public-data  stackoverflow  stackoverflow_posts
# 16  bigquery-public-data  stackoverflow  stackoverflow_posts
# 17  bigquery-public-data  stackoverflow  stackoverflow_posts
# 18  bigquery-public-data  stackoverflow  stackoverflow_posts
# 19  bigquery-public-data  stackoverflow  stackoverflow_posts
#
#                  column_name                field_path  data_type description
# 0                         id                        id      INT64        None
# 1                      title                     title     STRING        None
# 2                       body                      body     STRING        None
# 3         accepted_answer_id        accepted_answer_id      INT64        None
# 4               answer_count              answer_count      INT64        None
# 5              comment_count             comment_count      INT64        None
# 6       community_owned_date      community_owned_date  TIMESTAMP        None
# 7              creation_date             creation_date  TIMESTAMP        None
# 8             favorite_count            favorite_count      INT64        None
# 9         last_activity_date        last_activity_date  TIMESTAMP        None
# 10            last_edit_date            last_edit_date  TIMESTAMP        None
# 11  last_editor_display_name  last_editor_display_name     STRING        None
# 12       last_editor_user_id       last_editor_user_id      INT64        None
# 13        owner_display_name        owner_display_name     STRING        None
# 14             owner_user_id             owner_user_id      INT64        None
# 15                 parent_id                 parent_id      INT64        None
# 16              post_type_id              post_type_id      INT64        None
# 17                     score                     score      INT64        None
# 18                      tags                      tags     STRING        None
# 19                view_count                view_count      INT64        None

# %% [markdown]
# ## Doing a dry test with a query

# %%
client = bigquery.Client()

job_config = bigquery.QueryJobConfig()
job_config.dry_run = True
job_config.use_query_cache = False
query_job = client.query(
    ("""
    SELECT *
    FROM `bigquery-public-data.stackoverflow.stackoverflow_posts`
    """),
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
    job_config=job_config,
)  # API request

# A dry run query completes immediately.
assert query_job.state == "DONE"
assert query_job.dry_run

print("This query will process {} bytes ({} Gb).".format(query_job.total_bytes_processed, query_job.total_bytes_processed/1e+9))
# Out:
# This query will process 31523321609 bytes (31.523321609 Gb).

# %% [markdown]
# ## Creating a table

# %%
dataset_id ='test'

job_config = bigquery.QueryJobConfig()

# Set the destination table
table_ref = client.dataset(dataset_id).table('schema_stackoverflow')
job_config.destination = table_ref
sql = """
SELECT
 * 
FROM
 `bigquery-public-data.stackoverflow`.INFORMATION_SCHEMA.COLUMN_FIELD_PATHS
WHERE
 table_name="stackoverflow_posts"
"""

# Start the query, passing in the extra configuration.
query_job = client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=job_config)  # API request - starts the query
try:
    query_job.result()  # Waits for the query to finish
    print('Query results loaded to table {}'.format(table_ref.path))
except:
    print("An exception occurred: maybe the table already exist")
# Out:
# An exception occurred: maybe the table already exist

# %% [markdown]
# ## Viewing a table

# %%
client = bigquery.Client()

query = """SELECT
*
FROM
 `bigquery-public-data.stackoverflow.stackoverflow_posts`
WHERE tags="python"
"""
df = client.query(query).to_dataframe()
print(len(df))
df.head(20)
# Out:
# 46085
#           id                                              title  \
# 0   16478566  Matching filenames with list using a loop igno...
# 1   26219149                         Read File strip whitespace
# 2     992638      How to setup twill for python 2.6 on Windows?
# 3      85451  Python - time.clock() vs. time.time() - accuracy?
# 4    9027996         Recording a win or loss in a game of craps
# 5   18086963  How can I take two numbers and add multiply su...
# 6   36360469               Read .nc (netcdf) files using python
# 7   27390840                 Python Float Lost with Big Numbers
# 8   17503506  I have variable which asks for users input how...
# 9   16404721         Python search folder and make a Dictionary
# 10  24833369                            Search a list in a list
# 11  23229189              How to read a url directory in Python
# 12  27955584   Python dictionary value assignment from variable
# 13   9736301             Alternative to u'' for unicode strings
# 14  19134139          Python - why list method returns nothing?
# 15  27090468                    Compare german umlaut in Python
# 16  21489242  Is there a way to output multiple lists from a...
# 17  25574418  check if the second element of tuples in list ...
# 18  33906423  Reading some files and passing to a constructo...
# 19  32660761  running a python file thats in a diffrent dire...
#
#                                                  body  accepted_answer_id  \
# 0   <p>What I want to do is match a set of files a...                 NaN
# 1   <p>Working through CorePytho I can print a fil...                 NaN
# 2   <p>I have already downloaded twill 0.9. Also I...                 NaN
# 3   <p>Which is better to use for timing in Python...                 NaN
# 4   <p>So I have to create a game of craps that ta...           9028064.0
# 5   <p>So far I have this I'm trying to add on to ...          18087025.0
# 6   <p>I am trying to learn how to read .nc (netcd...          36360598.0
# 7   <p>I am working with some large numbers and ha...          27390969.0
# 8   <p>This is my code:-</p> <pre><code>print Welc...          17503511.0
# 9   <p>I need to make a Dictionary out of some fol...          16405037.0
# 10  <p>Say I have a list:</p> <pre><code>D = [str1...          24833724.0
# 11  <p>I can use the urllib module to open a url f...          23229928.0
# 12  <p>I have this routine:</p> <pre><code>def _ge...          27955611.0
# 13  <p>I have the following asp script which uses ...           9736394.0
# 14  <p>I found that from statement <code>li = str....          19134190.0
# 15  <p>I have a list of german words and I want to...          27090571.0
# 16  <p>Something like</p> <pre><code>x y = [expres...          21489290.0
# 17  <p>I would like to check if the second element...          25574455.0
# 18  <p>I have a class that needs a list of words t...          33907538.0
# 19  <p>Right now I am using the import command to ...          32660873.0
#
#     answer_count  comment_count community_owned_date  \
# 0              1              0                  NaT
# 1              1              0                  NaT
# 2              2              0                  NaT
# 3             14              2                  NaT
# 4              1              0                  NaT
# 5              1              2                  NaT
# 6              1              3                  NaT
# 7              1              4                  NaT
# 8              1              8                  NaT
# 9              1              8                  NaT
# 10             1              9                  NaT
# 11             1             13                  NaT
# 12             1              0                  NaT
# 13             1              0                  NaT
# 14             1              1                  NaT
# 15             1              3                  NaT
# 16             2              1                  NaT
# 17             2              2                  NaT
# 18             2              3                  NaT
# 19             2              5                  NaT
#
#                       creation_date  favorite_count  \
# 0  2013-05-10 08:59:22.727000+00:00             NaN
# 1  2014-10-06 14:36:43.520000+00:00             NaN
# 2  2009-06-14 10:57:27.983000+00:00             NaN
# 3  2008-09-17 17:09:13.330000+00:00           106.0
# 4  2012-01-27 01:41:40.637000+00:00             NaN
# 5  2013-08-06 17:44:43.930000+00:00             NaN
# 6  2016-04-01 15:43:36.213000+00:00             NaN
# 7  2014-12-09 23:32:02.863000+00:00             NaN
# 8  2013-07-06 13:36:46.463000+00:00             NaN
# 9  2013-05-06 18:18:14.490000+00:00             NaN
# 10 2014-07-18 20:35:03.283000+00:00             NaN
# 11 2014-04-22 20:08:15.960000+00:00             NaN
# 12 2015-01-15 01:46:22.413000+00:00             NaN
# 13 2012-03-16 11:19:14.417000+00:00             NaN
# 14 2013-10-02 09:47:47.850000+00:00             NaN
# 15 2014-11-23 15:14:28.590000+00:00             NaN
# 16 2014-01-31 20:16:05.070000+00:00             NaN
# 17 2014-08-29 18:46:14.783000+00:00             NaN
# 18 2015-11-25 00:23:23.980000+00:00             NaN
# 19 2015-09-18 20:47:24.033000+00:00             NaN
#
#                  last_activity_date                   last_edit_date  \
# 0  2013-05-10 09:12:41.887000+00:00                              NaT
# 1  2014-10-06 15:04:56.107000+00:00                              NaT
# 2  2009-06-14 11:03:37.410000+00:00                              NaT
# 3  2016-03-11 00:15:17.457000+00:00                              NaT
# 4  2012-01-27 02:01:37.573000+00:00 2012-01-27 02:00:35.190000+00:00
# 5  2013-08-06 18:00:55.810000+00:00 2013-08-06 18:00:55.810000+00:00
# 6  2016-04-01 16:30:56.913000+00:00 2016-04-01 16:30:56.913000+00:00
# 7  2014-12-10 00:32:22.337000+00:00 2014-12-10 00:32:22.337000+00:00
# 8  2013-07-06 13:52:43.653000+00:00 2013-07-06 13:52:43.653000+00:00
# 9  2013-05-06 18:39:39.897000+00:00 2013-05-06 18:30:12.443000+00:00
# 10 2014-07-18 20:59:19.707000+00:00 2014-07-18 20:40:58.647000+00:00
# 11 2014-04-27 05:54:33.413000+00:00 2014-04-22 20:53:42.660000+00:00
# 12 2015-01-15 01:49:49.093000+00:00                              NaT
# 13 2012-03-16 11:25:28.937000+00:00                              NaT
# 14 2013-10-02 09:50:18.517000+00:00                              NaT
# 15 2014-11-23 15:23:21.750000+00:00                              NaT
# 16 2014-02-01 01:22:39.083000+00:00 2014-01-31 23:58:00.633000+00:00
# 17 2014-08-29 19:10:10.397000+00:00 2014-08-29 18:48:14.657000+00:00
# 18 2015-11-25 02:47:02.317000+00:00 2015-11-25 00:30:59.860000+00:00
# 19 2015-09-28 22:40:32.870000+00:00 2015-09-28 22:40:32.870000+00:00
#
#    last_editor_display_name  last_editor_user_id owner_display_name  \
# 0                      None                  NaN        user2080223
# 1                      None                  NaN       Scott Parkis
# 2                      None                  NaN               None
# 3                      None                  NaN          cgoldberg
# 4                      None             972208.0               None
# 5                      None            1357341.0               None
# 6                      None            5609523.0               None
# 7                      None            4099593.0               None
# 8                      None            1104674.0               None
# 9                      None            2250175.0               None
# 10                     None            3845722.0               None
# 11                     None            2581912.0               None
# 12                     None                  NaN               None
# 13                     None                  NaN               None
# 14                     None                  NaN               None
# 15                     None                  NaN               None
# 16                     None            2585497.0               None
# 17                     None            1914034.0               None
# 18                     None             307283.0               None
# 19                     None            5200523.0               None
#
#     owner_user_id parent_id  post_type_id  score    tags  view_count
# 0             NaN      None             1      1  python          95
# 1       3298643.0      None             1     -1  python         136
# 2             NaN      None             1      0  python        1311
# 3         16148.0      None             1    317  python      282844
# 4       1172584.0      None             1      2  python         638
# 5       2657861.0      None             1     -3  python        2758
# 6       6093740.0      None             1      3  python          46
# 7       3483459.0      None             1      2  python          54
# 8       2021393.0      None             1      0  python          81
# 9       2250175.0      None             1      1  python          74
# 10      3845722.0      None             1     -1  python          64
# 11      2581912.0      None             1      0  python         132
# 12       425715.0      None             1      0  python          27
# 13       607846.0      None             1      0  python         133
# 14       605280.0      None             1      0  python          47
# 15       826983.0      None             1      2  python         139
# 16      2585497.0      None             1      3  python          69
# 17      1914034.0      None             1      0  python         194
# 18       307283.0      None             1      2  python          35
# 19      5200523.0      None             1      0  python          33
